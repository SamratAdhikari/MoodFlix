# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
books_df = pd.read_csv('assets/books.csv', usecols=lambda x: x != "id")
ratings_df = pd.read_csv('assets/ratings.csv')
book_tags_df = pd.read_csv('assets/book_tags.csv')
tags_df = pd.read_csv('assets/tags.csv')
to_read_df = pd.read_csv('assets/to_read.csv')

# %%
books_df.head()
# Out:
#    book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1        3             3  4640799          491  439554934  9.780440e+12
# 2    41865         41865  3212258          226  316015849  9.780316e+12
# 3     2657          2657  3275794          487   61120081  9.780061e+12
# 4     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  \
# 0                          The Hunger Games
# 1  Harry Potter and the Philosopher's Stone
# ...

# %%
ratings_df.head()
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4

# %%
book_tags_df.head()
# Out:
#    goodreads_book_id  tag_id   count
# 0                  1   30574  167697
# 1                  1   11305   37174
# 2                  1   11557   34173
# 3                  1    8717   12986
# 4                  1   33114   12716

# %%
tags_df.head()
# Out:
#    tag_id tag_name
# 0       0        -
# 1       1     --1-
# 2       2    --10-
# 3       3    --12-
# 4       4   --122-

# %%
to_read_df.head()
# Out:
#    user_id  book_id
# 0        1      112
# 1        1      235
# 2        1      533
# 3        1     1198
# 4        1     1874

# %%
print(books_df.shape)
print(ratings_df.shape)
print(book_tags_df.shape)
print(tags_df.shape)
print(to_read_df.shape)
# Out:
# (10000, 22)
# (981756, 3)
# (999912, 3)
# (34252, 2)
# (912705, 2)

# %%
books_df.isnull().sum()
# Out:
# book_id                         0
# best_book_id                    0
# work_id                         0
# books_count                     0
# isbn                          700
# isbn13                        585
# authors                         0
# original_publication_year      21
# original_title                585
# title                           0
# language_code                1084
# average_rating                  0
# ratings_count                   0
# work_ratings_count              0
# work_text_reviews_count         0
# ratings_1                       0
# ratings_2                       0
# ratings_3                       0
# ratings_4                       0
# ratings_5                       0
# image_url                       0
# small_image_url                 0
# dtype: int64

# %%
ratings_df.isnull().sum()
# Out:
# book_id    0
# user_id    0
# rating     0
# dtype: int64

# %%
book_tags_df.isnull().sum()
# Out:
# goodreads_book_id    0
# tag_id               0
# count                0
# dtype: int64

# %%
tags_df.isnull().sum()
# Out:
# tag_id      0
# tag_name    0
# dtype: int64

# %%
to_read_df.isnull().sum()
# Out:
# user_id    0
# book_id    0
# dtype: int64

# %%
tags = pd.merge(book_tags_df, right=tags_df, how='inner')
tags.head()
# Out:
#    goodreads_book_id  tag_id   count tag_name
# 0                  1   30574  167697  to-read
# 1                  2   30574   24549  to-read
# 2                  3   30574  496107  to-read
# 3                  5   30574   11909  to-read
# 4                  6   30574     298  to-read

# %%
books_and_tags_df = pd.merge(books_df, tags, how='inner', left_on='book_id', right_on='goodreads_book_id')
books_and_tags_df.head()
# Out:
#    book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 2  2767052       2767052  2792775          272  439023483  9.780439e+12
# 3  2767052       2767052  2792775          272  439023483  9.780439e+12
# 4  2767052       2767052  2792775          272  439023483  9.780439e+12
#
#            authors  original_publication_year    original_title  \
# 0  Suzanne Collins                     2008.0  The Hunger Games
# 1  Suzanne Collins                     2008.0  The Hunger Games
# 2  Suzanne Collins                     2008.0  The Hunger Games
# 3  Suzanne Collins                     2008.0  The Hunger Games
# 4  Suzanne Collins                     2008.0  The Hunger Games
#
#                                      title  ... ratings_2  ratings_3  \
# 0  The Hunger Games (The Hunger Games, #1)  ...    127936     560092
# ...

# %%
df = books_and_tags_df.groupby('book_id')['tag_name'].apply(' '.join).reset_index()
df.head()
# Out:
#    book_id                                           tag_name
# 0        1  to-read fantasy favorites currently-reading yo...
# 1        2  to-read fantasy favorites currently-reading yo...
# 2        3  to-read fantasy favorites currently-reading yo...
# 3        5  to-read fantasy favorites currently-reading yo...
# 4        6  to-read fantasy young-adult fiction harry-pott...

# %%
df = pd.merge(books_df, df, left_on='book_id', right_on='book_id', how='inner')
df.head()
# Out:
#    book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1        3             3  4640799          491  439554934  9.780440e+12
# 2    41865         41865  3212258          226  316015849  9.780316e+12
# 3     2657          2657  3275794          487   61120081  9.780061e+12
# 4     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  \
# 0                          The Hunger Games
# 1  Harry Potter and the Philosopher's Stone
# ...

# %%
df['corpus'] = (pd.Series(df[['authors', 'tag_name']].fillna('').values.tolist()).str.join(' '))

# %%
df.head()
# Out:
#    book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1        3             3  4640799          491  439554934  9.780440e+12
# 2    41865         41865  3212258          226  316015849  9.780316e+12
# 3     2657          2657  3275794          487   61120081  9.780061e+12
# 4     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  \
# 0                          The Hunger Games
# 1  Harry Potter and the Philosopher's Stone
# ...

# %%
tf_corpus = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix_corpus = tf_corpus.fit_transform(df['corpus'])
cosine_sim_corpus = linear_kernel(tfidf_matrix_corpus, tfidf_matrix_corpus)

# %%
titles = df['title']
indices = pd.Series(df.index, index=df['title'])


def corpus_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim_corpus[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    book_indices = [i[0] for i in sim_scores]

    return titles.iloc[book_indices]

# %%
corpus_recommendations("The Hobbit")
# Out:
# 188     The Lord of the Rings (The Lord of the Rings, ...
# 154            The Two Towers (The Lord of the Rings, #2)
# 160     The Return of the King (The Lord of the Rings,...
# 18      The Fellowship of the Ring (The Lord of the Ri...
# 610              The Silmarillion (Middle-Earth Universe)
# 4975         Unfinished Tales of Númenor and Middle-Earth
# 2308                                The Children of Húrin
# 963     J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
# 465                             The Hobbit: Graphic Novel
# 8271                   The Complete Guide to Middle-Earth
# Name: title, dtype: object

# %%
titles.iloc[188]
# Out:
# 'The Lord of the Rings (The Lord of the Rings, #1-3)'

# %%
cosine_sim_corpus
# Out:
# array([[1.        , 0.21246305, 0.25620524, ..., 0.04730357, 0.07394754,
#         0.01578042],
#        [0.21246305, 1.        , 0.20308655, ..., 0.04934815, 0.06629237,
#         0.02173749],
#        [0.25620524, 0.20308655, 1.        , ..., 0.0313175 , 0.03967015,
#         0.0137797 ],
#        ...,
#        [0.04730357, 0.04934815, 0.0313175 , ..., 1.        , 0.02524071,
#         0.06967423],
#        [0.07394754, 0.06629237, 0.03967015, ..., 0.02524071, 1.        ,
#         0.06947988],
#        [0.01578042, 0.02173749, 0.0137797 , ..., 0.06967423, 0.06947988,
#         1.        ]])

# %%
new_df = df[['book_id', 'original_title', 'image_url', 'corpus']]
new_df.iloc[0]['image_url']
# Out:
# 'https://images.gr-assets.com/books/1447303603m/2767052.jpg'

# %%
import pickle

pickle.dump(new_df, open('UI/books_list.pkl','wb'))
pickle.dump(cosine_sim_corpus, open('UI/book_similarity.pkl','wb'))
